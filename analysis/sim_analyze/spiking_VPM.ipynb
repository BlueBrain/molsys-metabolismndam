# %%
import numpy as np
import pandas as pd
import pickle

from matplotlib import pyplot as plt
#import seaborn as sns

# %% [markdown]
# ### Simulation 1.

# %% [markdown]
# block_name='whitenonrep',
#
# sampling='all_exp_all_units',
#
# time_window='from_start',
#
# sample_seed=None,
#
# data_root='/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/data_bale_spike_trains',
#
# t_offset=0.0
#
# ##### spikes(gids, 10000, data_root='/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/data_bale_spike_trains')

# %%
with open('/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simwriter/simwriter/tcin/bale_spikes/spikes_sgids_dur10k.pkl', 'rb') as handle:
    spikes = pickle.load(handle)
    

# add /scatter

data = []
for k,vv in spikes.items():
    for v in vv: 
        data.append( (v, k))

spcol = pd.DataFrame(data, columns=['spike_time','cell_id'])

spcol.head()

# %%
len(spcol['cell_id'].unique())
# Out:
# 555

# %%
#spcol.to_csv('/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simulation/spikes_sgids_dur10k_forBlueConfig_test.dat',sep='\t',header=None,index=False)
# add /scatter

# %%
sdf =  pd.DataFrame.from_dict(spikes,orient='index')

sdf = sdf.fillna(0)

sdfnp1 = sdf.to_numpy()

# %%
plt.eventplot(sdfnp1,linelengths=1,lineoffsets=1)

plt.savefig('/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simulation/plots/plot2_d10k.png')

plt.show()

# %%
plt.eventplot(sdfnp1,linelengths=1,lineoffsets=1)

plt.axis([0.0000001, 10002, 0, 431])

plt.savefig('/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simulation/plots/plot_spikes_from_VPM_dur10k.png')

plt.show()

# %% [markdown]
# ### Simulation 2.

# %% [markdown]
# block_name='p150',
#
# sampling='all_exp_all_units',
#
# time_window='from_start',
#
# sample_seed=None,
#
# data_root='/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/data_bale_spike_trains',
#
# t_offset=0.0
#
# ##### spikes(gids, 250, data_root='/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/data_bale_spike_trains')

# %%
with open('/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simwriter/simwriter/tcin/bale_spikes/spikes_sgids_dur250_p150.pkl', 'rb') as handle:
    spikes = pickle.load(handle)
    

# add /scatter

data = []
for k,vv in spikes.items():
    for v in vv: 
        data.append( (v, k))

spcol = pd.DataFrame(data, columns=['spike_time','cell_id'])

spcol.head()
# Out:
#    spike_time  cell_id
# 0   99.983616   250001
# 1   26.992709   250019
# 2  118.620464   250019
# 3  212.664864   250019
# 4  121.241910   250028

# %%
with open('/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simwriter/simwriter/tcin/bale_spikes/new_spikes_sgids_dur1000_whiterep_toffset1k_test.pkl', 'rb') as handle:
    spikes = pickle.load(handle)
    

# add /scatter

data = []
for k,vv in spikes.items():
    for v in vv: 
        data.append( (v, k))

spcol = pd.DataFrame(data, columns=['spike_time','cell_id'])

spcol.head()
# Out:
#     spike_time  cell_id
# 0  1060.620955   250000
# 1  1146.678135   250000
# 2  1535.594331   250000
# 3  1828.541001   250000
# 4  1063.692963   250001

# %%
len(spcol['cell_id'].unique())
# Out:
# 305

# %%
#spcol.to_csv('/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simulation/spikes_sgids_dur250_p150_forBlueConfig_test.dat',sep='\t',header=None,index=False)
# add /scatter

# %%
sdf =  pd.DataFrame.from_dict(spikes,orient='index')

# %%
sdf =  pd.DataFrame.from_dict(spikes,orient='index')

sdf = sdf.fillna(0)

sdfnp1 = sdf.to_numpy()

# %%
plt.eventplot(sdfnp1,linelengths=1,lineoffsets=1)

plt.axis([1000.0000001, 2000, 0, 350])

#plt.savefig('/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simulation/plots/plot_d250_p150.png')

plt.show()

# %%
#max
thal = pd.read_csv('/gpfs/bbp.cscs.ch/project/proj9/simulations/nolte/variability/evoked/base_seeds_exp_25/seed187/exp25.dat',sep='\t',skiprows=1,header=None)

# %%
thal.head()
# Out:
#          0       1
# 0  2493.96  221042
# 1  1957.71  221043
# 2  2006.25  221043
# 3  2024.64  221043
# 4  2045.57  221043

# %%
thal = thal.groupby(1).agg(lambda x: x.tolist())

# %%
thal.head()
# Out:
#                                                         0
# 1
# 221042                                          [2493.96]
# 221043  [1957.71, 2006.25, 2024.64, 2045.57, 2117.74, ...
# 221044  [2312.14, 2314.23, 2316.36, 2456.24, 2651.13, ...
# 221045  [1968.49, 2140.39, 2739.31, 2810.91, 3339.67, ...
# 221046  [1964.31, 2202.16, 2204.09, 2415.07, 2450.38, ...

# %%
df = pd.DataFrame([pd.Series(x) for x in thal[0]])
df.columns = ['t_{}'.format(x+1) for x in df.columns]

# %%
df.head()
# Out:
#        t_1      t_2      t_3      t_4      t_5      t_6      t_7      t_8  \
# 0  2493.96      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1  1957.71  2006.25  2024.64  2045.57  2117.74  2130.40  2137.45  2176.69
# 2  2312.14  2314.23  2316.36  2456.24  2651.13  2889.31  3040.17  3428.92
# 3  1968.49  2140.39  2739.31  2810.91  3339.67  4320.41  4677.26  5715.76
# 4  1964.31  2202.16  2204.09  2415.07  2450.38  3202.98  3893.90  4327.99
#
#        t_9     t_10  ...    t_133   t_134    t_135    t_136    t_137    t_138  \
# 0      NaN      NaN  ...      NaN     NaN      NaN      NaN      NaN      NaN
# 1  2201.71  2217.81  ...  6670.91  6690.2  6734.56  6780.97  6842.61  6851.34
# 2  3684.39  4082.27  ...      NaN     NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN  ...      NaN     NaN      NaN      NaN      NaN      NaN
# 4  4567.98  5184.06  ...      NaN     NaN      NaN      NaN      NaN      NaN
#
#      t_139  t_140  t_141  t_142
# ...

# %%
sdf = df.fillna(0)

sdfnp1 = sdf.to_numpy()

# %%
plt.eventplot(sdfnp1,linelengths=1,lineoffsets=1)

plt.axis([2000.0000001, 3000, 0, 350])

plt.show()

# %% [markdown]
# ### Simulation 3.

# %% [markdown]
# block_name='whiterep',
#
# sampling='all_exp_all_units',
#
# time_window='from_start',
#
# sample_seed=None,
#
# data_root='/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/data_bale_spike_trains',
#
# t_offset=0.0
#
# ##### spikes(gids, 250, data_root='/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/data_bale_spike_trains')

# %%
with open('/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simwriter/simwriter/tcin/bale_spikes/spikes_sgids_dur250_whiterep.pkl', 'rb') as handle:
    spikes = pickle.load(handle)
    

# add /scatter

data = []
for k,vv in spikes.items():
    for v in vv: 
        data.append( (v, k))

spcol = pd.DataFrame(data, columns=['spike_time','cell_id'])

spcol.head()
# Out:
#    spike_time  cell_id
# 0   66.273450   250008
# 1  151.224707   250008
# 2   59.801753   250012
# 3  108.052757   250014
# 4  211.313181   250014

# %%
len(spcol['cell_id'].unique())
# Out:
# 291

# %%
#spcol.to_csv('/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simulation/spikes_sgids_dur250_whiterep_forBlueConfig.dat',sep='\t',header=None,index=False)
# add /scatter

# %%
sdf =  pd.DataFrame.from_dict(spikes,orient='index')

sdf = sdf.fillna(0)

sdfnp1 = sdf.to_numpy()

# %%
plt.eventplot(sdfnp1,linelengths=1,lineoffsets=1)

plt.axis([0.0000001, 260, 0, 300])

#plt.savefig('/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simulation/plots/plot_d250_whiterep.png')

plt.show()

# %% [markdown]
# ### Simulation 4.

# %% [markdown]
# block_name='whiterep',
#
# sampling='all_exp_all_units',
#
# time_window='from_start',
#
# sample_seed=None,
#
# data_root='/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/data_bale_spike_trains',
#
# t_offset=0.0
#
# ##### spikes(gids, 1000, data_root='/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/data_bale_spike_trains')

# %%
with open('/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simwriter/simwriter/tcin/bale_spikes/spikes_sgids_dur1000_whiterep.pkl', 'rb') as handle:
    spikes = pickle.load(handle)
    

# add /scatter

data = []
for k,vv in spikes.items():
    for v in vv: 
        data.append( (v, k))

spcol = pd.DataFrame(data, columns=['spike_time','cell_id'])

spcol.head()
# Out:
#    spike_time  cell_id
# 0  593.061358   250000
# 1  596.051446   250000
# 2  152.166790   250004
# 3  190.013926   250004
# 4  446.301303   250004

# %%
len(spcol['cell_id'].unique())
# Out:
# 451

# %%
#spcol.to_csv('/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simulation/spikes_sgids_dur1000_whiterep_forBlueConfig.dat',sep='\t',header=None,index=False)
# add /scatter

# %%
pd.read_csv('/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simulation/spikes_sgids_dur1000_whiterep_forBlueConfig.dat',sep='\t',header=None,skiprows=1)

# %%
with open('/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simwriter/simwriter/tcin/bale_spikes/spikes_sgids_dur1000_whiterep.pkl', 'rb') as handle:
    spikes = pickle.load(handle)

# %%
sdf =  pd.DataFrame.from_dict(spikes,orient='index')

sdf = sdf.fillna(0)

sdfnp1 = sdf.to_numpy()

# %%
plt.eventplot(sdfnp1,linelengths=1,lineoffsets=1)

plt.axis([0.0000001, 250, 0, 300])

#plt.savefig('/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simulation/plots/plot_d1000_whiterep.png')

plt.show()

# %% [markdown]
# ### Simulation 5.

# %% [markdown]
# block_name='p150',
#
# sampling='all_exp_all_units',
#
# time_window='from_start',
#
# sample_seed=None,
#
# data_root='/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/data_bale_spike_trains',
#
# t_offset=0.0
#
# ##### spikes(gids, 1000, data_root='/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/data_bale_spike_trains')

# %%
with open('/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simwriter/simwriter/tcin/bale_spikes/spikes_sgids_dur1000_p150.pkl', 'rb') as handle:
    spikes = pickle.load(handle)
    

# add /scatter

data = []
for k,vv in spikes.items():
    for v in vv: 
        data.append( (v, k))

spcol = pd.DataFrame(data, columns=['spike_time','cell_id'])

spcol.head()
# Out:
#    spike_time  cell_id
# 0  690.996969   250000
# 1  692.963054   250000
# 2  694.806259   250000
# 3  819.324977   250000
# 4  143.810928   250001

# %%
len(spcol['cell_id'].unique())
# Out:
# 340

# %%
#spcol.to_csv('/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simulation/spikes_sgids_dur1000_p150_forBlueConfig.dat',sep='\t',header=None,index=False)
# add /scatter

# %%
sdf =  pd.DataFrame.from_dict(spikes,orient='index')

sdf = sdf.fillna(0)

sdfnp1 = sdf.to_numpy()

# %%
plt.eventplot(sdfnp1,linelengths=1,lineoffsets=1)

plt.axis([0.0000001, 1010, 0, 350])

#plt.savefig('/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simulation/plots/plot_d1000_p150.png')

plt.show()

# %% [markdown]
# ### Example

# %%
#from example
indat = pd.read_csv('/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simulation/input.dat',skiprows=1,sep='\t',header=None)

# %%
indat.head()
# Out:
#              0       1
# 0  2001.292358  250000
# 1  2022.458618  250000
# 2  2240.861328  250000
# 3  2426.833008  250000
# 4  2466.690674  250000

# %%
indatw = indat.groupby(1)[0].apply(list).reset_index(name='list_times')

indatw = indatw.list_times.apply(pd.Series)
indatw = indatw.fillna(0)

# %%
indatw = indatw.fillna(0)

# %%
#indatw 

#.fillna(0)
indatwnp = indatw.to_numpy()

# %%
plt.eventplot(indatwnp,linelengths=1,lineoffsets=1)

plt.axis([0.0000001, 10002, 0, 431]) # 407

#plt.savefig('/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simulation/plots/plot_spikes_from_indat.png')

plt.show()

# %% [markdown]
# ### Long run: 5000ms

# %% [markdown]
# ##### p150

# %%
p150_1000 = pd.read_csv("/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simulation/full_detailed_sim_p150_v1/etypes_test/spikes_sgids_dur1000_p150_forBlueConfig.dat",
                       sep="\t",skiprows=1,header=None)

p150_2000 = p150_1000.copy()

p150_2000[0] = p150_2000[0] + 1000.0

p150_3000 = p150_1000.copy()

p150_3000[0] = p150_3000[0] + 2000.0

p150_4000 = p150_1000.copy()

p150_4000[0] = p150_4000[0] + 3000.0


p150_5000 = p150_1000.copy()

p150_5000[0] = p150_5000[0] + 4000.0


p150_longrun5000 = pd.concat([p150_1000,p150_2000,p150_3000,p150_4000,p150_5000])


p150_longrun5000 = p150_longrun5000.reset_index(drop=True)

p150_longrun5000 = p150_longrun5000.sort_values([1,0]).reset_index(drop=True)

p150_longrun5000.to_csv("/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simulation/full_detailed_sim_p150_v1/etypes_test/spikes_sgids_dur1000rep5_p150_forBlueConfig.dat", 
                       sep="\t",index=None,header=None)
# Out:
#             0       1
# 0  690.996969  250000
# 1  692.963054  250000
# 2  694.806259  250000
# 3  819.324977  250000
# 4  143.810928  250001

# %%
# new 1dec2020

p150_1000 = pd.read_csv("/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simulation/full_detailed_sim_p150_v1/etypes_test/spikes_sgids_dur1000_p150_forBlueConfig.dat",
                       sep="\t",skiprows=1,header=None)

p150_2000 = p150_1000.copy()

p150_2000[0] = p150_2000[0] + 1000.0

p150_3000 = p150_1000.copy()

p150_3000[0] = p150_3000[0] + 2000.0

p150_4000 = p150_1000.copy()

p150_4000[0] = p150_4000[0] + 3000.0


p150_longrun5000 = pd.concat([p150_2000,p150_3000,p150_4000])


p150_longrun5000 = p150_longrun5000.reset_index(drop=True)

p150_longrun5000 = p150_longrun5000.sort_values([1,0]).reset_index(drop=True)

#p150_longrun5000.to_csv("/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simulation/full_detailed_sim_p150_v1/etypes_test/spikes_sgids_dur1000rep3_from1kTo4k_p150_forBlueConfig.dat", 
#                       sep="\t",index=None,header=None)

# %%
# new 26feb2021

p150_1000 = pd.read_csv("/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simulation/full_detailed_sim_p150_v1/etypes_test/spikes_sgids_dur1000_p150_forBlueConfig.dat",
                       sep="\t",skiprows=1,header=None)


p150_1000[0] = p150_1000[0] + 1000.0

p150_1000 = p150_1000.sort_values([0,1]).reset_index(drop=True)

#p150_1000.to_csv("/gpfs/bbp.cscs.ch/project/proj34/metabolismndam/sim/spikes_p150/spikes_sgids_dur1000_from1kTo2k_p150_forBlueConfig.dat", 
#                       sep="\t",index=None,header=None)

#/scatter

# %%
# new 8mar2021


with open('/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simwriter/simwriter/tcin/bale_spikes/new_spikes_sgids_dur1000_p150.pkl', 'rb') as handle:
    spikes = pickle.load(handle)
    

# add /scatter

data = []
for k,vv in spikes.items():
    for v in vv: 
        data.append( (v, k))

spcol = pd.DataFrame(data, columns=['spike_time','cell_id'])

spcol.head()
# Out:
#    spike_time  cell_id
# 0   33.505366   250000
# 1  308.798231   250000
# 2  395.060211   250000
# 3  476.939461   250000
# 4  950.970754   250000

# %%
# new 9mar2021


with open('/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simwriter/simwriter/tcin/bale_spikes/new_spikes_sgids_dur1000_whiterep_toffset1k.pkl', 'rb') as handle:
    spikes = pickle.load(handle)
    

# add /scatter

data = []
for k,vv in spikes.items():
    for v in vv: 
        data.append( (v, k))

spcol = pd.DataFrame(data, columns=['spike_time','cell_id'])

spcol.head()
# Out:
#     spike_time  cell_id
# 0  1149.504383   250000
# 1  1072.663226   250001
# 2  1134.758745   250001
# 3  1144.261489   250001
# 4  1146.719096   250001

# %%
# new 11mar2021


with open('/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simwriter/simwriter/tcin/bale_spikes/spikes_sgids_dur1000_p150_toffset1k_11mar2021.pkl', 'rb') as handle:
    spikes = pickle.load(handle)
    

# add /scatter

data = []
for k,vv in spikes.items():
    for v in vv: 
        data.append( (v, k))

spcol = pd.DataFrame(data, columns=['spike_time','cell_id'])

spcol.head()
# Out:
#     spike_time  cell_id
# 0  1257.516179   250000
# 1  1259.482264   250000
# 2  1261.284509   250000
# 3  1263.905956   250000
# 4  1856.516753   250000

# %%
plt.plot(spcol['spike_time'],spcol['cell_id'],'.')
plt.show()

# %%
plt.hist(spcol['spike_time'],bins=100)
plt.show()

# %%
len(spcol['cell_id'].unique())
# Out:
# 176

# %%
spcol['spike_time'].min()
# Out:
# 1003.8092897517572

# %%
spcol['spike_time'].max()
# Out:
# 1998.894077168643

# %%
spcol['cell_id'].max()
# Out:
# 250406

# %%
plt.hist(spcol['spike_time'],bins=100)
plt.show()

# %%
#spcol.to_csv('/gpfs/bbp.cscs.ch/project/proj34/metabolismndam/sim/spikes_p150/spikes_sgids_dur1000_whiterep_9mar2021.dat',sep='\t',header=None,index=False)
# add /scatter

# %%
#spcol.to_csv('/gpfs/bbp.cscs.ch/project/proj34/metabolismndam/sim/spikes_p150/spikes_sgids_dur1000_forBlueConfig_8mar2021.dat',sep='\t',header=None,index=False)
# add /scatter

# %%
spcol = spcol.sort_values(['spike_time','cell_id']).reset_index(drop=True)

# %%
spcol.head()
# Out:
#     spike_time  cell_id
# 0  1000.778242   250148
# 1  1005.693455   250218
# 2  1016.015401   250253
# 3  1016.097321   250273
# 4  1018.063406   250273

# %%
#spcol.to_csv('/gpfs/bbp.cscs.ch/project/proj34/metabolismndam/sim/spikes_p150/spikes_sgids_dur1000_p150_newProj_11mar2021.dat',sep='\t',header=None,index=False)
# add /scatter

# %%
# new 8mar2021

p150_1000 = pd.read_csv("/gpfs/bbp.cscs.ch/project/proj34/metabolismndam/sim/spikes_p150/spikes_sgids_dur1000_forBlueConfig_8mar2021.dat",
                       sep="\t",skiprows=1,header=None)


p150_1000[0] = p150_1000[0] + 1000.0

p150_1000 = p150_1000.sort_values([0,1]).reset_index(drop=True)

#p150_1000.to_csv("/gpfs/bbp.cscs.ch/project/proj34/metabolismndam/sim/spikes_p150/spikes_sgids_dur1000_from1kTo2k_p150_8mar2021.dat", 
#                       sep="\t",index=None,header=None)

#/scatter

# %%
# new 9mar2021

p150_1000 = pd.read_csv("/gpfs/bbp.cscs.ch/project/proj34/metabolismndam/sim/spikes_p150/spikes_sgids_dur1000_whiterep_9mar2021.dat",
                       sep="\t",skiprows=1,header=None)

p150_1000 = p150_1000.sort_values([0,1]).reset_index(drop=True)

#p150_1000.to_csv("/gpfs/bbp.cscs.ch/project/proj34/metabolismndam/sim/spikes_p150/spikes_sgids_dur1000_from1kTo2k_whiterep_9mar2021.dat", 
#                       sep="\t",index=None,header=None)

#/scatter

# %%
#p150_1000.to_csv("/gpfs/bbp.cscs.ch/project/proj34/metabolismndam/sim/spikes_p150/spikes_sgids_dur1000_from1kTo2k_whiterep_9mar2021.dat", 
#                       sep="\t",index=None,header=None)

# %%
p150_1000.head()
# Out:
#              0       1
# 0  1003.809290  250331
# 1  1005.693455  250242
# 2  1014.540837  250140
# 3  1015.441960  250178
# 4  1026.214467  250361

# %%
#allthal = pd.read_csv("/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simwriter/simwriter/tcin/bale_spikes/projection_sgids.txt",
#                       skiprows=0,header=None)

# %%
allthal.head()
# Out:
#         0
# 0  250000
# 1  250001
# 2  250002
# 3  250003
# 4  250004

# %%
import random

# %%
times = np.random.random((len(allthal[0]),1))

# %%
allthal['times'] = times

# %%
allthal['times']  = allthal['times'] + 1200

# %%
allthal = allthal.reindex(columns=['times',0])

# %%
allthal.head()
# Out:
#          times       0
# 0  1200.002329  250351
# 1  1200.003927  250381
# 2  1200.004973  250365
# 3  1200.008948  250250
# 4  1200.014299  250278

# %%
allthal = allthal.sort_values(['times',0]).reset_index(drop=True)

# %%
#allthal.to_csv("/gpfs/bbp.cscs.ch/project/proj34/metabolismndam/sim/spikes_p150/spikes_sgids_test.dat", 
#                       sep="\t",index=None,header=None)

# %%
len(allthal[0])
# Out:
# 407

# %%
len(p150_1000[1].unique())
# Out:
# 297

# %%
plt.hist(p150_1000[0],bins=100)
plt.show()

# %%
plt.hist(p150_1000[0],bins=100)
plt.show()

# %%
np.max(p150_1000[1])
# Out:
# 250609

# %%
p150_1000.loc[p150_1000[1]==250609]
# Out:
#               0       1
# 400  1410.01065  250609

# %%
p150_1000 = pd.read_csv("/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simulation/full_detailed_sim_p150_v1/etypes_test/spikes_sgids_dur1000_p150_forBlueConfig.dat",
                       sep="\t",skiprows=1,header=None)

p150_2000 = p150_1000.copy()

p150_2000[0] = p150_2000[0] + 1000.0

p150_3000 = p150_1000.copy()

p150_3000[0] = p150_3000[0] + 2000.0

p150_4000 = p150_1000.copy()

p150_4000[0] = p150_4000[0] + 3000.0


p150_5000 = p150_1000.copy()

p150_5000[0] = p150_5000[0] + 4000.0


p150_longrun5000 = pd.concat([p150_1000,p150_2000,p150_3000,p150_4000,p150_5000])


p150_longrun5000 = p150_longrun5000.reset_index(drop=True)

p150_longrun5000 = p150_longrun5000.sort_values([1,0]).reset_index(drop=True)

#p150_longrun5000.to_csv("/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simulation/full_detailed_sim_p150_v1/etypes_test/spikes_sgids_dur1000rep5_p150_forBlueConfig.dat", 
#                       sep="\t",index=None,header=None)

# %%
p150_1000 = pd.read_csv("/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simulation/full_detailed_sim_p150_v1/etypes_test/spikes_sgids_dur1000_p150_forBlueConfig.dat",
                       sep="\t",skiprows=1,header=None)

p150_2000 = p150_1000.copy()

p150_2000[0] = p150_2000[0] + 1000.0

p150_3000 = p150_1000.copy()

p150_3000[0] = p150_3000[0] + 2000.0

p150_4000 = p150_1000.copy()

p150_4000[0] = p150_4000[0] + 3000.0

p150_5000 = p150_1000.copy()

p150_5000[0] = p150_5000[0] + 4000.0

p150_6000 = p150_1000.copy()

p150_6000[0] = p150_6000[0] + 5000.0

p150_7000 = p150_1000.copy()

p150_7000[0] = p150_7000[0] + 6000.0

p150_8000 = p150_1000.copy()

p150_8000[0] = p150_8000[0] + 7000.0

p150_9000 = p150_1000.copy()

p150_9000[0] = p150_9000[0] + 8000.0

p150_10000 = p150_1000.copy()

p150_10000[0] = p150_10000[0] + 9000.0



p150_longrun10k = pd.concat([p150_1000,p150_2000,p150_3000,p150_4000,p150_5000,p150_6000,p150_7000,p150_8000,p150_9000,p150_10000])


p150_longrun10k = p150_longrun10k.reset_index(drop=True)

p150_longrun10k = p150_longrun10k.sort_values([1,0]).reset_index(drop=True)

#p150_longrun10k.to_csv("/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simulation/full_detailed_sim_p150_v1/etypes_test/spikes_sgids_dur1000rep10_p150_forBlueConfig.dat", 
#                       sep="\t",index=None,header=None)

# %%
whiterep_1000 = pd.read_csv("/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simulation/full_detailed_sim_whiterep_v1/spikes_sgids_dur1000_whiterep_forBlueConfig.dat",
                       sep="\t",skiprows=1,header=None)

whiterep_2000 = whiterep_1000.copy()

whiterep_2000[0] = whiterep_2000[0] + 1000.0

whiterep_3000 = whiterep_1000.copy()

whiterep_3000[0] = whiterep_3000[0] + 2000.0

whiterep_4000 = whiterep_1000.copy()

whiterep_4000[0] = whiterep_4000[0] + 3000.0


whiterep_5000 = whiterep_1000.copy()

whiterep_5000[0] = whiterep_5000[0] + 4000.0


whiterep_longrun5000 = pd.concat([whiterep_1000,whiterep_2000,whiterep_3000,whiterep_4000,whiterep_5000])


whiterep_longrun5000 = whiterep_longrun5000.reset_index(drop=True)

whiterep_longrun5000 = whiterep_longrun5000.sort_values([1,0]).reset_index(drop=True)

#whiterep_longrun5000.to_csv("/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simulation/full_detailed_sim_whiterep_v1/spikes_sgids_dur1000rep5_whiterep_forBlueConfig.dat", 
#                       sep="\t",index=None,header=None)

# %%
whiterep_1000 = pd.read_csv("/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simulation/full_detailed_sim_whiterep_v1/spikes_sgids_dur1000_whiterep_forBlueConfig.dat",
                       sep="\t",skiprows=1,header=None)

whiterep_2000 = whiterep_1000.copy()

whiterep_2000[0] = whiterep_2000[0] + 1000.0

whiterep_3000 = whiterep_1000.copy()

whiterep_3000[0] = whiterep_3000[0] + 2000.0

whiterep_4000 = whiterep_1000.copy()

whiterep_4000[0] = whiterep_4000[0] + 3000.0

whiterep_5000 = whiterep_1000.copy()

whiterep_5000[0] = whiterep_5000[0] + 4000.0

whiterep_6000 = whiterep_1000.copy()

whiterep_6000[0] = whiterep_6000[0] + 5000.0

whiterep_7000 = whiterep_1000.copy()

whiterep_7000[0] = whiterep_7000[0] + 6000.0

whiterep_8000 = whiterep_1000.copy()

whiterep_8000[0] = whiterep_8000[0] + 7000.0

whiterep_9000 = whiterep_1000.copy()

whiterep_9000[0] = whiterep_9000[0] + 8000.0

whiterep_10000 = whiterep_1000.copy()

whiterep_10000[0] = whiterep_10000[0] + 9000.0



whiterep_longrun10k = pd.concat([whiterep_1000,whiterep_2000,whiterep_3000,whiterep_4000,whiterep_5000,whiterep_6000,whiterep_7000,whiterep_8000,whiterep_9000,whiterep_10000])


whiterep_longrun10k = whiterep_longrun10k.reset_index(drop=True)

whiterep_longrun10k = whiterep_longrun10k.sort_values([1,0]).reset_index(drop=True)

#whiterep_longrun10k.to_csv("/gpfs/bbp.cscs.ch/home/shichkov/dan/nrnsteps/invivolike/simulation/full_detailed_sim_whiterep_v1/spikes_sgids_dur1000rep10_whiterep_forBlueConfig.dat", 
 #                      sep="\t",index=None,header=None)

# %%
# !pwd
# Out:
# /gpfs/bbp.cscs.ch/home/shichkov/sim_analyze
